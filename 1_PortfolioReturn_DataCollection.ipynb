# %% [markdown]
# # **Prediction of a Stocks Portfolio Return using Recurrent Neural Networks**
# _____

# %% [markdown]
# Author: **Daniel Eduardo López**
#
# #####<a href="https://www.linkedin.com/in/daniel-eduardo-lopez"> LinkedIn </a>
#
# #####<a href="https://github.com/DanielEduardoLopez"> GitHub </a>

# %% [markdown]
# ![pexels-pixabay-534216.jpg](data:image/jpeg;base64,...)
#
# ##### Image Credit: <a href="https://www.pexels.com/es-es/foto/numeros-en-el-monitor-534216/"> Pixabay </a>

# %% [markdown]
# ### **1. Goal**
#
# The purpose of the present notebook is to define the components of the stock portofolio, retrieve the stocks value data by using the Yahoo Finance API, calculate the returns and optimize the portfolio composition to maximize the return.
#
# ___

# %% [markdown]
# ### **1. Introduction**
#
#
# In this context, it is desired to assess the accuracy of the predictions of a RNN on the return of a stocks portfolio.
#
# ___

# %% [markdown]
# ### **2. General Objective**
#
# To predict the return of a stocks portfolio Return using Recurrent Neural Networks.
# ___

# %% [markdown]
# ### **3. Research Question**
# What is the return of a stocks portfolio according to a model based on Recurrent Neural Networks?
#
# ___
